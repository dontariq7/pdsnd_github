# %%
import time
import pandas as pd
import numpy as np
CITY_DATA = { 'chicago': 'chicago.csv',
              'new york city': 'new_york_city.csv',
              'washington': 'washington.csv' }
def get_filters():
    """
    Asks user to specify a city, month, and day to analyze.
    Returns:
        (str) city - name of the city to analyze
        (str) month - name of the month to filter by, or "all" to apply no month filter
        (str) day - name of the day of week to filter by, or "all" to apply no day filter
    """
    print('Hello! Let\'s explore some US bikeshare data!')
    # TO DO: get user input for city (chicago, new york city, washington). HINT: Use a while loop to handle invalid inputs
    
    """
    1- Ask the user what city they want, and store their answer in a variable.. I called mine city
    2- while city is neither chicago nor new york city not washington, ask the user to enter a valid city name
    Recommendations & hints:
    - Use the input() function to get the user's input
    - Use a while loop to repeat user prompting until a valid city name is entered
    - You may use .strip() on the input, in case the user enters an extra space
    """
    # TO DO: get user input for month (all, january, february, ... , june)
    """
    1- Use input to get desired month from the user, and store it in a variable. I called mine month
    Recommedations & hint:
    - You may use .capitalize() or .title() methods to capitalize the user input (m)
        references:
            https://www.w3schools.com/python/ref_string_capitalize.asp 
            https://www.w3schools.com/python/ref_string_title.asp
    """
    # TO DO: get user input for day of week (all, monday, tuesday, ... sunday)
    """
    Similar to month
    """
    print('-'*40)
    return city, month, day
def load_data(city, month, day):
    """
    Loads data for the specified city and filters by month and day if applicable.
    Args:
        (str) city - name of the city to analyze
        (str) month - name of the month to filter by, or "all" to apply no month filter
        (str) day - name of the day of week to filter by, or "all" to apply no day filter
    Returns:
        df - Pandas DataFrame containing city data filtered by month and day
    """
    # filtered by the city
    df = pd.read_csv(CITY_DATA[city])
    
    # convert the start and end times from strings to dates, so we can extract the day/month from them
    df['Start Time'] = pd.to_datetime(df['Start Time'])
    df['End Time'] = pd.to_datetime(df['End Time'])
    
    # extract the day and month into their separate columns
    df['day'] = df['Start Time'].dt.day_name()
    df['month'] = df['Start Time'].dt.month_name()
    """
    Unlike the classroom exercise, I am using day_name() and month_name() to get the day and month
    names instead of numbers.
    """
    # filter by month if applicable
    if month != 'All':
        df = df[df['month'] == month]
        
    # filter by day of week if applicable
    if day != 'All': 
        # filter by day of week to create the new dataframe
        df = df[df['day'] == day]
    """
    Note that I used All here instead of all in the classroom exercise. This is because I capitalized the user input for
    the month. You may or may not need to do this, depending on your logic.
    """
    return df
def time_stats(df):
    """Displays statistics on the most frequent times of travel."""
    print('\nCalculating The Most Frequent Times of Travel...\n')
    start_time = time.time()
    # TO DO: display the most common month
    # TO DO: display the most common day of week
    
    # TO DO: display the most common start hour
    df['hour'] = df['Start Time'].dt.hour
    popular_hour = df['hour'].mode()[0]
    print("Most common start hour:\n{} \n".format(popular_hour))
    """
    This is from the classroom exercises, so I am leaving it :)
    What is happening here?
    - We are extracting the hour from the start time (which includes the full date and time)
    - We are storing the extracted hour in a new column in the data frame
    - We are using the .mode() method to get the most common hour
    - the [0] at the end is there because the result of .mode() is a pandas series of size 1. We are using the index 
        label to get the data.
    The most popular day & month can be found directly, as a "day" and a "month" columns already exist (we added
    them in the load_data function when we filtered)
    Therefore, all you have to do for the hour & the month is use .mode()[0]
    """
    print("\nThis took %s seconds." % (time.time() - start_time))
    print('-'*40)
def station_stats(df):
    """Displays statistics on the most popular stations and trip."""
    print('\nCalculating The Most Popular Stations and Trip...\n')
    start_time = time.time()
    # TO DO: display most commonly used start station
    """
    Same as the day & month.. call mode on the 'Start Station' column, which already exists. 
    """
    
    
    # TO DO: display most commonly used end station
    """
    Same .. call mode on the 'End Station' column, which already exists. 
    """
    # TO DO: display most frequent combination of start station and end station trip
    
    """
    for this one I created a new column which I called route. route is equal to the start station + the end station.
    In other words, I added two other columns to create this one.
    Remember, to get a column, use df[column_name].
    After that, I found the most frequent value in this new route column, using the mode method, 
    just like we did with the rest.
    """
    
    print("\nThis took %s seconds." % (time.time() - start_time))
    print('-'*40)
def trip_duration_stats(df):
    """Displays statistics on the total and average trip duration."""
    print('\nCalculating Trip Duration...\n')
    start_time = time.time()
    # TO DO: display total travel time
    
    """
    the total travel time is equal to the sum of all the values in the 'Trip Duration' column.
    Have a look at the following links, for an extra hint:
    - https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.sum.html
    - https://www.geeksforgeeks.org/python-pandas-dataframe-sum/ 
    """
    # TO DO: display mean travel time
    """
    Pretty straight-forward.. there is a function to find the mean in pandas, which you need to apply to 'Trip Duration'. 
    I'll leave this one to you, look it up if you are unsure :) 
    """
    print("\nThis took %s seconds." % (time.time() - start_time))
    print('-'*40)
def user_stats(df):
    """Displays statistics on bikeshare users."""
    print('\nCalculating User Stats...\n')
    start_time = time.time()
    # TO DO: Display counts of user types
    """
    My first thought was to use groupby and count for this one..
    Turned out there is a .value_counts() method that is helpful here
    Reference: https://www.pythonprogramming.in/pandas-count-distinct-values-of-a-dataframe-column.html
    """
    # TO DO: Display counts of gender
    """
    Similar to the previous one
    """
    # TO DO: Display earliest, most recent, and most common year of birth
    """
    Hints:
    - The target column is 'Birth Year'
    - The earliest birth year is going to be the minimum in that column
    - The most recent birth year is going to be the maximum in that column
    - The most common is ?????
    """
    print("\nThis took %s seconds." % (time.time() - start_time))
    print('-'*40)
